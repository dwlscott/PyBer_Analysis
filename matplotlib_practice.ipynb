# %%
# %matplotlib inline

# %%
# Import dependencies.
import matplotlib.pyplot as plt

# %%
# St the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot 
plt.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.plot(x_axis, y_axis)

# %%
# Create the plot with and ax.plt()

fig = plt.figure()

ax = fig.add_subplot()

ax.plot(x_axis, y_axis)

# %%
# To create a quck graph using the object-oriented interface method 

# Create the plot with ax.plt()

ax = plt.axes()
ax.plot(x_axis, y_axis)

# %%
# Create  the plot and add a label for the legend. 
plt.plot(x_axis, y_axis, label='Boston')

#create lables for the x and y axis
plt.xlabel("Date")
plt.ylabel("Fare($)")

# Set the y limt between 0 and 45
plt.ylim(0, 45)

# Create a title.
plt.title("PyBer Fare by the Month")

# Add the legend. 
plt.legend()

# %%
# Create the plot
plt.plot(x_axis, y_axis, marker="*", color="blue", linewidth=2, label='Boston')

# Create lables for the x and y axes 
plt.xlabel("Date")
plt.ylabel("Fare($)")

#set the Y limit to 0 and 45
plt.ylim(0, 45)

# Create a title 
plt.title("PyBer Fare By Month")

# Add a grid()
plt.grid()

# Add a legend.
plt.legend()

# %%
# Skill check using opbject oriented approach, 

ax = plt.axes()
# Create the plot 
# Change the marker to a diamond 
# Change the line width to 2 points 
ax.plot(x_axis, y_axis, marker='D', color='green', linewidth=2, label='Boston')

# Add a y_axis limit 
ax.set_ylim(0, 45)

# Add a legend for the city of Boston. 
ax.legend()

# Add a title 
ax.set_title("PyBer Fare by Month")

# Add lables for the And y Axis 
ax.set_xlabel("Date")
ax.set_ylabel("Fare ($)")

#Add a Grid line 
ax.grid()

# %%
# Create the plot
plt.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot 
plt.bar(x_axis, y_axis, color="green", label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
# Create the plot
plt.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot.. if we want to switch the axises literally just switch them. 
plt.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot.
plt.barh(x_axis, y_axis)
plt.gca().invert_yaxis()

# %%
# Create the plot 
plt.barh(x_axis, y_axis, color="magenta")

# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")

# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Skill check using opbject oriented approach, 

# Create the plot with ax.plt()
fig, ax = plt.subplots()

#Change the bar color to cyan.
#Add a legend for the city of Chicago.
ax.barh(x_axis, y_axis, color= "cyan", label= "Chicago")

#invert the y_axis data 
plt.gca().invert_yaxis()

#Add a title and axes labels.
#Switch the axis so that the Fare($) data is on the x-axis.
plt.title("PyBer Fare by Month")
plt.xlabel("Fare ($)")
plt.ylabel("Date")

# Add a ledgend for the city of Chicago 
plt.legend()

# %%
#scatter plot practice 

plt.plot(x_axis, y_axis, 'o')

# %%
# Create the plot 
plt.plot(y_axis, x_axis,'o', color="red", label="chicago")

#invert the y_axis so that naunary is at the top 
plt.gca().invert_yaxis()

# Create labels for the x and y axes.
plt.ylabel("Date")
plt.xlabel("Fare($)")


# Create a title.
plt.title("PyBer Fare by Month")

#Add a limit for the x-axis
plt.xlim(0, 50)
      
# Add the legend.
plt.legend()

# %%
plt.scatter(x_axis, y_axis, s=y_axis)

# %%
y_axis_larger = []
for data in y_axis:
  y_axis_larger.append(data*3)

# %%
plt.scatter(x_axis, y_axis, s=y_axis_larger)

# %%
plt.scatter(x_axis, y_axis, s = [i * 3 for i in y_axis])

# %%
# Creating Scatter plots using the Object_oriented Interface 

fig, ax = plt.subplots()
ax. scatter(x_axis, y_axis)

# %%
# Create a bubble chart using the object_oriendted interface 
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis, s=y_axis)

# %%
# Skill drill Using the object-oriented approach, make the following changes to your bubble chart:

#Change the color of the markers to sky blue (im confused why i couldent use color= "sky blue"...,. but okay)
#Make the color 20% transparent. alpha fxn
#Add a black edge color to the circles.
#Make the linewidth of the circles 2 points.
#Change the size of the markers to 5 times each data point.
fig, ax = plt.subplots()
ax.scatter(y_axis, x_axis,alpha= 0.2, edgecolor="black", linewidth=2, s = [i * 5 for i in y_axis], label="Boston") 




#Add a legend for the city of Boston.
ax.legend()

#Add a title.
#Switch the axis so that the Fare($) data is on the x-axis.
plt.title("PyBer Fare by Month")
plt.xlabel("Fare ($)")
plt.ylabel("Date")

#Add a limit for the x-axis data.
plt.xlim(0, 55)

#Invert the y-axis so that January is at the top.
plt.gca().invert_yaxis()

# %%
#Create a pie chart 
plt.pie(y_axis, labels=x_axis)
plt.show()

# %%
# Making the pie chart more impactful 
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)

plt.pie(y_axis, explode=explode_values, labels=x_axis, autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fd8b9845af0>,
#   <matplotlib.patches.Wedge at 0x7fd8b9856160>,
#   <matplotlib.patches.Wedge at 0x7fd8b9856850>,
#   <matplotlib.patches.Wedge at 0x7fd8b9856f70>,
#   <matplotlib.patches.Wedge at 0x7fd8b98646d0>,
#   <matplotlib.patches.Wedge at 0x7fd8b9864df0>,
#   <matplotlib.patches.Wedge at 0x7fd8b9870550>,
#   <matplotlib.patches.Wedge at 0x7fd8b9870c70>,
#   <matplotlib.patches.Wedge at 0x7fd8b987f3d0>,
#   <matplotlib.patches.Wedge at 0x7fd8b987faf0>,
#   <matplotlib.patches.Wedge at 0x7fd8b97b79d0>,
#   <matplotlib.patches.Wedge at 0x7fd8b988d940>],
#  [Text(1.0940372721655667, 0.11437852557419124, 'Jan'),
#   Text(0.9905193092273052, 0.4784051609753622, 'Feb'),
#   Text(0.4998632656180861, 0.9798656620606842, 'Mar'),
#   Text(-0.32930826971286276, 1.0495504101750999, 'April'),
#   Text(-0.9306200792045569, 0.5864693241605263, 'May'),
#   Text(-1.0983369533258995, -0.06046434452452757, 'June'),
#   Text(-0.913463027456946, -0.9249785389235748, 'July'),
#   Text(-0.23338752507546193, -1.0749559354406817, 'Aug'),
#   Text(0.021097559209412746, -1.099797660024518, 'Sept'),
#   Text(0.460981299980763, -0.9987473359504124, 'Oct'),
#   Text(0.8868706338501641, -0.6507384104340302, 'Nov'),
#   Text(1.0760953148482877, -0.22807646384834376, 'Dec')],
#  [Text(0.5967476029993999, 0.06238828667683158, '3.3%'),
#   Text(0.5402832595785301, 0.2609482696229248, '7.7%'),
#   Text(0.27265269033713785, 0.5344721793058277, '13.0%'),
#   Text(-0.17962269257065241, 0.5724820419136908, '11.7%'),
#   Text(-0.5076109522933946, 0.3198923586330143, '10.7%'),
#   Text(-0.5990928836323088, -0.03298055155883321, '8.9%'),
#   Text(-0.562131093819659, -0.5692175624145076, '14.5%'),
#   Text(-0.1273022864047974, -0.5863396011494626, '3.5%'),
#   Text(0.011507759568770587, -0.5998896327406462, '3.9%'),
#   Text(0.2514443454440525, -0.5447712741547703, '9.2%'),
#   Text(0.4837476184637258, -0.35494822387310737, '6.9%'),
#   Text(0.5869610808263387, -0.12440534391727841, '6.6%')])

# %%
# Assign 12 colors, one for each month.
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.subplots(figsize=(8, 8))
plt.pie(y_axis,
    explode=explode_values,
    colors=colors,
    labels=x_axis,
    autopct='%.1f%%')

plt.show()

# %%
fig, ax = plt.subplots()
ax.pie(y_axis,labels=x_axis)
plt.show()

# %%
# Skill drill Using the object-oriented approach, make the following changes to the pie chart: my brain hurts come back to this

#Add a percentage to one decimal place to each wedge of the pie.
#Increase the figure size to 8x8.
#Explode the two highest percentage months.
#Add a shadow.
#Add a start angle so that January is at the top.
#Reverse the order so that the month order is in a clockwise direction.
#Add new colors of your own choosing or use the colors from the previous pie chart.

fig, ax = plt.subplots(figsize=8,8))

ax.pie(y_axis, explode=explode_values, colors=colors, shadow=True, startangle=90, counterclock=false, labels=x_axis, autopct='%.1f%%')
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]

explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)



plt.show()
# Out:
#   File "/var/folders/qh/sfq990ys7p998_z3t2wwb7940000gn/T/ipykernel_824/99279652.py", line 11
#     fig, ax = plt.subplots(figsize=8,8))
#                                       ^
# SyntaxError: positional argument follows keyword argument

# %%
# lets add some error bars to a line chart 
plt.errorbar(x, y, yerr=<value>)
# Out:
#   File "/var/folders/qh/sfq990ys7p998_z3t2wwb7940000gn/T/ipykernel_824/707963353.py", line 2
#     plt.errorbar(x, y, yerr=<value>)
#                             ^
# SyntaxError: invalid syntax

# %%
# Import dependencies.
import matplotlib.pyplot as plt
import statistics

# %%
# Get the standard deviation of the values in the y-axis
stdev = statistics.stdev(y_axis)
stdev
# make it look more professional by adding a "cap to the error bar "
plt.errorbar(x_axis, y_axis, yerr=stdev, capsize =3)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
# Add erro bar and a capsize using the OO approach 
fig, ax = plt.subplots()
ax.errorbar(x_axis, y_axis, yerr=stdev, capsize=3)
plt.show()

# %%
#Add error bars to a bar chart 
plt.bar(x_axis, y_axis, yerr=stdev, capsize=3)
# Out:
# <BarContainer object of 12 artists>

# %%
#Add error bars to a bar chart using the OO method
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis, yerr=stdev, capsize=3)
plt.show()

# %%
# Change the major ticks 
import numpy as np
plt.barh(x_axis, y_axis)
plt.xticks(np.arange(0, 51, step=5.0))
plt.gca().invert_yaxis()

# %%
# Adding somemore insight to ticks...?
import numpy as np
np.arange(0, 51, step=5.0)
# Out:
# array([ 0.,  5., 10., 15., 20., 25., 30., 35., 40., 45., 50.])

# %%
# We can create the same graph using the OOapproach 
fig, ax = plt.subplots()
ax. barh(x_axis, y_axis)
ax.set_xticks(np.arange(0, 51, step= 5.0))
plt.show()

# %%
# add minor ticks 
from matplotlib.ticker import MultipleLocator
# Increase the size of the plot figure.
fig, ax = plt.subplots(figsize=(8, 8))
ax.barh(x_axis, y_axis)
ax.set_xticks(np.arange(0, 51, step=5.0))

# Create minor ticks at an increment of 1.
ax.xaxis.set_minor_locator(MultipleLocator(1))
plt.show()
